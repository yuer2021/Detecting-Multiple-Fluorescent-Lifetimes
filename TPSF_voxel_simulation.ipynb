# %%
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt

mnist = fetch_openml('mnist_784', cache=False)
X = mnist.data.astype('float32') / 255.0
y = mnist.target.astype('int64')

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
assert(X_train.shape[0] + X_test.shape[0] == mnist.data.shape[0])
X_train.shape, y_train.shape

# randomly select an MNIST figure and plot it
num_of_images = X_train.shape[0]
random_idx = np.random.randint(num_of_images)
plt.imshow(X_train.values[random_idx].reshape(28,28))

# %%
# generate biexponential parameters
def generate_params(image):
    #generate random lifetime values for the 28x28 binary image, each pixel was assigned 4 values at random, short-lifetime(tau1), long-lifetime(tau2), fractional amplitude(A1, A2)
    m = image.shape[0]
    n = image.shape[1]
    
    #tau1 values between 0.4-0.7ns, tau2 values between 2-3ns, A1 and A2 values between 0-1
    tau1_threshold = np.random.rand(m,n) * 0.3 + 0.4
    tau2_threshold = np.random.rand(m,n) * 1 + 2
    tau1 = tau1_threshold * image;
    tau2 = tau2_threshold * image;
    a1 = np.random.rand(m, n) * image;
    a2 = np.random.rand(m, n) * image;
    return tau1, tau2, a1,a2

# generate Intensity
def generate_intensity(image):
    #generate random intensity values for the 28x28 binary image
    m = image.shape[0]
    n = image.shape[1]
    
    #photon count values between 250-1500 p.c.
    intensity_threshold = np.random.rand(m, n) * 1250 + 250
    intensity = intensity_threshold * image
    return intensity

# %%
# performs convolution
def conv(a,b):
    A = np.fft.fft(a)
    B = np.fft.fft(b)
    C = A * B
    return abs(np.fft.ifft(C)/np.sum(a))

# %%
def generate_tpsf(intensity, tau1, tau2, a1, a2, irf_lib):
    M = intensity.shape[0]
    N = intensity.shape[1]
    #number of Time-Points
    nTP = 256
    time = np.arange(0,nTP,1)
    #dimension of one TPSF is image*time(28*28*nTP)
    voxel_data = np.zeros((M,N,nTP))
    irf = np.zeros((M,N,nTP))
    for i in range(M):
      for j in range(N):
        #generate fluorescence decays (Γ(𝑡)) at each nonzero pixel location
        if tau1[i,j]:
          decay = a1[i,j] * np.exp(-time.T/tau1[i,j]) + a2[i,j] * np.exp(-time.T/tau2[i,j])
          irf = irf_lib[:, np.random.randint(irf_lib.shape[1])]
          decay = conv(decay,irf/sum(irf))
          noise = np.random.normal(0, 0.1,decay.shape)
          decay = decay * intensity[i,j] + noise
          #assign the decay to its corresponding pixel location
          voxel_data[i,j,:] = decay / max(decay)
    return voxel_data

# %%
import scipy.io
mat = scipy.io.loadmat('FLIM_IRF.mat')
irf_lib = mat['irf_whole']

image = X_train.values[random_idx].reshape(28,28)
intensity = generate_intensity(image)
[tau1, tau2, a1, a2] = generate_params(image)
one_image_tpsfs = generate_tpsf(intensity, tau1, tau2, a1, a2, irf_lib)

#plot TPSF of the fist 2 nonezero pixels and print relevant parameters
def plot_pixel_TPSF():
    is_break = False
    n = 0
    for i in range(28):
      for j in range(28):
        if tau1[i,j]:
          time = np.arange(0,256,1)
          I = one_image_tpsfs[i, j, :]
          plt.plot(time[:100], I[:100])
          print("tau1", tau1[i,j])
          print("tau2", tau2[i,j])
          print("a1", a1[i,j])
          print("a2", a2[i,j], '\n')
          n += 1
          if n == 2:
            is_break = True
        if is_break:
          break
      if is_break:
        break
plot_pixel_TPSF()
# Out:
# tau1 0.24347636810189716
# tau2 1.070092146522766
# a1 0.32701872212754324
# a2 0.2526572341518529
#
# tau1 0.30654357994909526
# tau2 1.4611145682930975
# a1 0.511233804777071
# a2 0.4236307322523079

# %%
def generate_a_small_training_set():
    input_voxels = []
    inten_vals = []
    tau1_vals = []
    tau2_vals = []
    a1_vals = []
    a2_vals = []
    for imageIdx in range(1600):
      image = X_train.values[random_idx].reshape(28,28)
      intensity = generate_intensity(image)
      [tau1, tau2, a1, a2] = generate_params(image)
      one_image_tpsfs = generate_tpsf(intensity, tau1, tau2, a1, a2, irf_lib)
      input_voxels.append(one_image_tpsfs)
      inten_vals.append(intensity)
      tau1_vals.append(tau1)
      tau2_vals.append(tau2)
      a1_vals.append(a1)
      a2_vals.append(a2)
    return np.array(input_voxels), np.array(inten_vals), np.array(tau1_vals), np.array(tau2_vals), np.array(a1_vals), np.array(a2_vals)

# %%
def generate_a_small_testing_set():
    input_voxels = []
    inten_vals = []
    tau1_vals = []
    tau2_vals = []
    a1_vals = []
    a2_vals = []
    for imageIdx in range(1600,2000):
      image = X_train.values[random_idx].reshape(28,28)
      intensity = generate_intensity(image)
      [tau1, tau2, a1, a2] = generate_params(image)
      one_image_tpsfs = generate_tpsf(intensity, tau1, tau2, a1, a2, irf_lib)
      input_voxels.append(one_image_tpsfs)
      inten_vals.append(intensity)
      tau1_vals.append(tau1)
      tau2_vals.append(tau2)
      a1_vals.append(a1)
      a2_vals.append(a2)
    return np.array(input_voxels), np.array(inten_vals), np.array(tau1_vals), np.array(tau2_vals), np.array(a1_vals), np.array(a2_vals)

# %%
train_input_voxels, train_intensity, train_tau1, train_tau2, train_a1, train_a2 = generate_a_small_training_set()
test_input_voxels, test_intensity, test_tau1, test_tau2, test_a1, test_a2 = generate_a_small_testing_set()

#Introduce the channel dimention in the input dataset
xtrain = train_input_voxels[..., np.newaxis]
ytrain_tau1 = train_tau1[...,np.newaxis]
ytrain_tau2 = train_tau2[...,np.newaxis]
ytrain_a1 = train_a1[...,np.newaxis]
ytrain_a2 = train_a2[...,np.newaxis]

xtest = test_input_voxels[..., np.newaxis]
ytest_tau1 = test_tau1[...,np.newaxis]
ytest_tau2 = test_tau2[...,np.newaxis]
ytest_a1 = test_a1[...,np.newaxis]
ytest_a2 = test_a2[...,np.newaxis]

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Flatten, Conv3D, MaxPooling3D, Dropout, BatchNormalization, Conv2D, MaxPooling2D, Reshape

# %%
#Define a convolutional neural network
def get_model():

    inputs = keras.Input((28, 28, 256, 1))

    x = Conv3D(filters=16, kernel_size=(1,1,10), activation="relu")(inputs)
    # x = MaxPooling3D(pool_size=(2, 2, 2))(x)
    x = BatchNormalization()(x)

    # x = Conv3D(filters=32, kernel_size=(1,1,10), activation="relu")(x)
    # # x = MaxPooling3D(pool_size=(2, 2, 2))(x)
    # x = BatchNormalization()(x)

    # x = Conv3D(filters=64, kernel_size=(1,1,10), activation="relu")(x)
    # # x = MaxPooling3D(pool_size=(2, 2, 2))(x)
    # x = BatchNormalization()(x)

    x = Conv3D(filters=32, kernel_size=(1,1,10), activation="relu")(x)
    # x = MaxPooling3D(pool_size=(2, 2, 2))(x)
    x = BatchNormalization()(x)

    # x = GlobalAveragePooling3D()(x)
    # x = Dense(units=512, activation="relu")(x)
    # x = Dropout(0.3)(x)

    x = Reshape((28,28,-1))(x)

    t1 = Conv2D(filters =8, kernel_size = 1, activation="relu")(x)
    # t1 = MaxPooling2D(pool_size=(2, 2))(t1)
    t1 = BatchNormalization()(t1)
    t1 = Conv2D(1, 1, padding='same', activation=None)(t1)
    # t1 = BatchNormalization()(t1)
    # t1 = Conv2D(1, 1, padding='same', activation=None)(t1)


    t2 = Conv2D(filters =8, kernel_size = 1, activation="relu")(x)
    # t2 = MaxPooling2D(pool_size=(2, 2))(t2)
    t2 = BatchNormalization()(t2)
    t2 = Conv2D(1, 1, padding='same', activation=None)(t2)
    # t2 = BatchNormalization()(t2)
    # t2 = Conv2D(1, 1, padding='same', activation=None)(t2)

    a1 = Conv2D(filters =8, kernel_size = 1, activation="relu")(x)
    # a1 = MaxPooling2D(pool_size=(2, 2))(a1)
    a1 = BatchNormalization()(a1)
    a1 = Conv2D(1, 1, padding='same', activation=None)(a1)
    # a1 = BatchNormalization()(a1)
    # a1 = Conv2D(1, 1, padding='same', activation=None)(a1)

    a2 = Conv2D(filters =8, kernel_size = 1, activation="relu")(x)
    # a2 = MaxPooling2D(pool_size=(2, 2))(a2)
    a2 = BatchNormalization()(a2)
    a2 = Conv2D(1, 1, padding='same', activation=None)(a2)
    # a2 = BatchNormalization()(a2)
    # a2 = Conv2D(1, 1, padding='same', activation=None)(a2)

    # Define the model.
    model = keras.Model([inputs], [t1,t2,a1,a2], name="3dcnn")
    return model

# Build model.
model = get_model()
model.summary()
# Out:
# Model: "3dcnn"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 28, 28, 256  0           []
#                                 , 1)]
#
#  conv3d (Conv3D)                (None, 28, 28, 247,  176         ['input_1[0][0]']
#                                  16)
#
#  batch_normalization (BatchNorm  (None, 28, 28, 247,  64         ['conv3d[0][0]']
#  alization)                      16)
#
#  conv3d_1 (Conv3D)              (None, 28, 28, 238,  5152        ['batch_normalization[0][0]']
#                                  32)
#
#  batch_normalization_1 (BatchNo  (None, 28, 28, 238,  128        ['conv3d_1[0][0]']
#  rmalization)                    32)
#
#  reshape (Reshape)              (None, 28, 28, 7616  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  conv2d (Conv2D)                (None, 28, 28, 8)    60936       ['reshape[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 28, 28, 8)    60936       ['reshape[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 28, 28, 8)    60936       ['reshape[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 28, 28, 8)    60936       ['reshape[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 28, 28, 8)   32          ['conv2d[0][0]']
#  rmalization)
#
#  batch_normalization_3 (BatchNo  (None, 28, 28, 8)   32          ['conv2d_2[0][0]']
#  rmalization)
#
#  batch_normalization_4 (BatchNo  (None, 28, 28, 8)   32          ['conv2d_4[0][0]']
#  rmalization)
#
#  batch_normalization_5 (BatchNo  (None, 28, 28, 8)   32          ['conv2d_6[0][0]']
#  rmalization)
#
#  conv2d_1 (Conv2D)              (None, 28, 28, 1)    9           ['batch_normalization_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 28, 28, 1)    9           ['batch_normalization_3[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 28, 28, 1)    9           ['batch_normalization_4[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 28, 28, 1)    9           ['batch_normalization_5[0][0]']
#
# ==================================================================================================
# Total params: 249,428
# Trainable params: 249,268
# Non-trainable params: 160
# __________________________________________________________________________________________________

# %%
#training the model
model.compile(loss = 'mse',
              metrics=['mae'])

# %%
#fitting the model
history = model.fit(x=[xtrain], y=[ytrain_tau1,ytrain_tau2,ytrain_a1,ytrain_a2],
          batch_size = 20,
          epochs = 50,
          verbose = 1,
          validation_split=0.2)
# Out:
# Epoch 1/50
# 64/64 [==============================] - 841s 13s/step - loss: 0.4669 - conv2d_1_loss: 0.0738 - conv2d_3_loss: 0.2016 - conv2d_5_loss: 0.1201 - conv2d_7_loss: 0.0714 - conv2d_1_mae: 0.0765 - conv2d_3_mae: 0.1473 - conv2d_5_mae: 0.1005 - conv2d_7_mae: 0.0694 - val_loss: 2.2521 - val_conv2d_1_loss: 0.1542 - val_conv2d_3_loss: 0.4451 - val_conv2d_5_loss: 1.3491 - val_conv2d_7_loss: 0.3037 - val_conv2d_1_mae: 0.3814 - val_conv2d_3_mae: 0.4737 - val_conv2d_5_mae: 1.1515 - val_conv2d_7_mae: 0.5402
# Epoch 2/50
# 64/64 [==============================] - 837s 13s/step - loss: 0.0559 - conv2d_1_loss: 0.0090 - conv2d_3_loss: 0.0240 - conv2d_5_loss: 0.0128 - conv2d_7_loss: 0.0101 - conv2d_1_mae: 0.0312 - conv2d_3_mae: 0.0510 - conv2d_5_mae: 0.0442 - conv2d_7_mae: 0.0367 - val_loss: 4.5815 - val_conv2d_1_loss: 0.3420 - val_conv2d_3_loss: 0.4657 - val_conv2d_5_loss: 3.0980 - val_conv2d_7_loss: 0.6758 - val_conv2d_1_mae: 0.5626 - val_conv2d_3_mae: 0.5441 - val_conv2d_5_mae: 1.7540 - val_conv2d_7_mae: 0.8109
# Epoch 3/50
# 64/64 [==============================] - 836s 13s/step - loss: 0.0368 - conv2d_1_loss: 0.0043 - conv2d_3_loss: 0.0163 - conv2d_5_loss: 0.0092 - conv2d_7_loss: 0.0070 - conv2d_1_mae: 0.0240 - conv2d_3_mae: 0.0395 - conv2d_5_mae: 0.0356 - conv2d_7_mae: 0.0308 - val_loss: 4.7357 - val_conv2d_1_loss: 0.3440 - val_conv2d_3_loss: 0.3766 - val_conv2d_5_loss: 3.3968 - val_conv2d_7_loss: 0.6182 - val_conv2d_1_mae: 0.5725 - val_conv2d_3_mae: 0.4573 - val_conv2d_5_mae: 1.8290 - val_conv2d_7_mae: 0.7790
# Epoch 4/50
# 64/64 [==============================] - 838s 13s/step - loss: 0.0286 - conv2d_1_loss: 0.0032 - conv2d_3_loss: 0.0121 - conv2d_5_loss: 0.0072 - conv2d_7_loss: 0.0061 - conv2d_1_mae: 0.0201 - conv2d_3_mae: 0.0336 - conv2d_5_mae: 0.0290 - conv2d_7_mae: 0.0279 - val_loss: 4.8625 - val_conv2d_1_loss: 0.3023 - val_conv2d_3_loss: 0.3082 - val_conv2d_5_loss: 3.2001 - val_conv2d_7_loss: 1.0519 - val_conv2d_1_mae: 0.5414 - val_conv2d_3_mae: 0.4227 - val_conv2d_5_mae: 1.7682 - val_conv2d_7_mae: 1.0197
# Epoch 5/50
# 64/64 [==============================] - 837s 13s/step - loss: 0.0293 - conv2d_1_loss: 0.0025 - conv2d_3_loss: 0.0150 - conv2d_5_loss: 0.0066 - conv2d_7_loss: 0.0052 - conv2d_1_mae: 0.0194 - conv2d_3_mae: 0.0315 - conv2d_5_mae: 0.0280 - conv2d_7_mae: 0.0239 - val_loss: 6.7069 - val_conv2d_1_loss: 0.0793 - val_conv2d_3_loss: 0.3892 - val_conv2d_5_loss: 4.8511 - val_conv2d_7_loss: 1.3873 - val_conv2d_1_mae: 0.2579 - val_conv2d_3_mae: 0.5328 - val_conv2d_5_mae: 2.1997 - val_conv2d_7_mae: 1.1695
# Epoch 6/50
# 64/64 [==============================] - 840s 13s/step - loss: 0.0215 - conv2d_1_loss: 0.0021 - conv2d_3_loss: 0.0089 - conv2d_5_loss: 0.0058 - conv2d_7_loss: 0.0047 - conv2d_1_mae: 0.0155 - conv2d_3_mae: 0.0270 - conv2d_5_mae: 0.0257 - conv2d_7_mae: 0.0243 - val_loss: 2.7402 - val_conv2d_1_loss: 0.4727 - val_conv2d_3_loss: 0.1946 - val_conv2d_5_loss: 1.7309 - val_conv2d_7_loss: 0.3420 - val_conv2d_1_mae: 0.6760 - val_conv2d_3_mae: 0.2082 - val_conv2d_5_mae: 1.2583 - val_conv2d_7_mae: 0.5544
# Epoch 7/50
# 64/64 [==============================] - 891s 14s/step - loss: 0.0202 - conv2d_1_loss: 0.0017 - conv2d_3_loss: 0.0082 - conv2d_5_loss: 0.0056 - conv2d_7_loss: 0.0047 - conv2d_1_mae: 0.0144 - conv2d_3_mae: 0.0267 - conv2d_5_mae: 0.0247 - conv2d_7_mae: 0.0234 - val_loss: 12.4769 - val_conv2d_1_loss: 1.6680 - val_conv2d_3_loss: 1.1020 - val_conv2d_5_loss: 7.8011 - val_conv2d_7_loss: 1.9058 - val_conv2d_1_mae: 1.2355 - val_conv2d_3_mae: 1.0268 - val_conv2d_5_mae: 2.7654 - val_conv2d_7_mae: 1.3577
# Epoch 8/50
# 64/64 [==============================] - 900s 14s/step - loss: 0.0189 - conv2d_1_loss: 0.0017 - conv2d_3_loss: 0.0072 - conv2d_5_loss: 0.0054 - conv2d_7_loss: 0.0046 - conv2d_1_mae: 0.0158 - conv2d_3_mae: 0.0258 - conv2d_5_mae: 0.0248 - conv2d_7_mae: 0.0229 - val_loss: 13.0252 - val_conv2d_1_loss: 1.6746 - val_conv2d_3_loss: 1.4118 - val_conv2d_5_loss: 9.8569 - val_conv2d_7_loss: 0.0819 - val_conv2d_1_mae: 1.2265 - val_conv2d_3_mae: 1.1607 - val_conv2d_5_mae: 3.0712 - val_conv2d_7_mae: 0.1389
# Epoch 9/50
# 64/64 [==============================] - 844s 13s/step - loss: 0.0183 - conv2d_1_loss: 0.0016 - conv2d_3_loss: 0.0070 - conv2d_5_loss: 0.0053 - conv2d_7_loss: 0.0044 - conv2d_1_mae: 0.0142 - conv2d_3_mae: 0.0253 - conv2d_5_mae: 0.0242 - conv2d_7_mae: 0.0225 - val_loss: 6.1869 - val_conv2d_1_loss: 0.8523 - val_conv2d_3_loss: 0.6475 - val_conv2d_5_loss: 3.3751 - val_conv2d_7_loss: 1.3121 - val_conv2d_1_mae: 0.8831 - val_conv2d_3_mae: 0.7873 - val_conv2d_5_mae: 1.8095 - val_conv2d_7_mae: 1.1028
# Epoch 10/50
# 64/64 [==============================] - 841s 13s/step - loss: 0.0174 - conv2d_1_loss: 0.0015 - conv2d_3_loss: 0.0065 - conv2d_5_loss: 0.0051 - conv2d_7_loss: 0.0043 - conv2d_1_mae: 0.0143 - conv2d_3_mae: 0.0238 - conv2d_5_mae: 0.0230 - conv2d_7_mae: 0.0226 - val_loss: 3.2787 - val_conv2d_1_loss: 0.7768 - val_conv2d_3_loss: 0.7126 - val_conv2d_5_loss: 0.1346 - val_conv2d_7_loss: 1.6546 - val_conv2d_1_mae: 0.8297 - val_conv2d_3_mae: 0.8255 - val_conv2d_5_mae: 0.1893 - val_conv2d_7_mae: 1.2361
# Epoch 11/50
# 64/64 [==============================] - 841s 13s/step - loss: 0.0167 - conv2d_1_loss: 0.0014 - conv2d_3_loss: 0.0060 - conv2d_5_loss: 0.0049 - conv2d_7_loss: 0.0043 - conv2d_1_mae: 0.0138 - conv2d_3_mae: 0.0248 - conv2d_5_mae: 0.0233 - conv2d_7_mae: 0.0212 - val_loss: 74.4908 - val_conv2d_1_loss: 3.8135 - val_conv2d_3_loss: 64.8020 - val_conv2d_5_loss: 4.0564 - val_conv2d_7_loss: 1.8189 - val_conv2d_1_mae: 1.8150 - val_conv2d_3_mae: 7.4432 - val_conv2d_5_mae: 1.9113 - val_conv2d_7_mae: 1.2699
# Epoch 12/50
# 64/64 [==============================] - 830s 13s/step - loss: 0.0160 - conv2d_1_loss: 0.0014 - conv2d_3_loss: 0.0057 - conv2d_5_loss: 0.0048 - conv2d_7_loss: 0.0042 - conv2d_1_mae: 0.0132 - conv2d_3_mae: 0.0226 - conv2d_5_mae: 0.0229 - conv2d_7_mae: 0.0211 - val_loss: 389.1746 - val_conv2d_1_loss: 65.8274 - val_conv2d_3_loss: 90.9269 - val_conv2d_5_loss: 156.0833 - val_conv2d_7_loss: 76.3370 - val_conv2d_1_mae: 7.4842 - val_conv2d_3_mae: 8.8478 - val_conv2d_5_mae: 11.5383 - val_conv2d_7_mae: 8.0591
# Epoch 13/50
# 64/64 [==============================] - 829s 13s/step - loss: 0.0154 - conv2d_1_loss: 0.0013 - conv2d_3_loss: 0.0053 - conv2d_5_loss: 0.0047 - conv2d_7_loss: 0.0041 - conv2d_1_mae: 0.0130 - conv2d_3_mae: 0.0211 - conv2d_5_mae: 0.0232 - conv2d_7_mae: 0.0210 - val_loss: 155.0633 - val_conv2d_1_loss: 29.7740 - val_conv2d_3_loss: 120.2419 - val_conv2d_5_loss: 3.8908 - val_conv2d_7_loss: 1.1564 - val_conv2d_1_mae: 5.0441 - val_conv2d_3_mae: 10.1658 - val_conv2d_5_mae: 1.8430 - val_conv2d_7_mae: 1.0092
# Epoch 14/50
# 64/64 [==============================] - 834s 13s/step - loss: 0.0150 - conv2d_1_loss: 0.0013 - conv2d_3_loss: 0.0050 - conv2d_5_loss: 0.0046 - conv2d_7_loss: 0.0041 - conv2d_1_mae: 0.0135 - conv2d_3_mae: 0.0220 - conv2d_5_mae: 0.0225 - conv2d_7_mae: 0.0206 - val_loss: 63.4921 - val_conv2d_1_loss: 15.4748 - val_conv2d_3_loss: 46.6994 - val_conv2d_5_loss: 0.2019 - val_conv2d_7_loss: 1.1161 - val_conv2d_1_mae: 3.6382 - val_conv2d_3_mae: 6.3288 - val_conv2d_5_mae: 0.4324 - val_conv2d_7_mae: 0.9879
# Epoch 15/50
# 33/64 [==============>...............] - ETA: 6:24 - loss: 0.0146 - conv2d_1_loss: 0.0012 - conv2d_3_loss: 0.0048 - conv2d_5_loss: 0.0046 - conv2d_7_loss: 0.0040 - conv2d_1_mae: 0.0129 - conv2d_3_mae: 0.0199 - conv2d_5_mae: 0.0216 - conv2d_7_mae: 0.0203

# %%
#evaluating and printing results
score = model.evaluate([xtest], [ytest_tau1,ytest_tau2,ytest_a1,ytest_a2])
# score = model.evaluate([xtrain[:200]], [ytrain_tau1[:200],ytrain_tau2[:200],ytrain_a1[:200],ytrain_a2[:200]], verbose = 0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])

# %%
testV = model.predict(xtest[:1])
t1P = testV[0]
t2P = testV[1]
a1P = testV[2]
a2P = testV[3]

# %%
t1G = ytest_tau1[:1]
t2G = ytest_tau2[:1]
a1G = ytest_a1[:1]
a2G = ytest_a2[:1]

# %%
plt.imshow(t1G.reshape(28,28))
# plt.imshow(X_train.values[random_idx].reshape(28,28))

# %%
plt.imshow(t1P.reshape(28,28))
